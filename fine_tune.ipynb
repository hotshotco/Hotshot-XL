# %%
# !accelerate launch Hotshot-XL/fine_tune.py \
    --output_dir="/home/vitap/Desktop/t2v dataset/Default Size/" \
    --data_dir="/home/vitap/Desktop/t2v dataset/new" \
    --report_to="wandb" \
    --run_validation_at_start \
    --resolution=512 \
    --mixed_precision=bfp16 \
    --train_batch_size=4 \
    --learning_rate=1.25e-05 \
    --lr_scheduler="constant" \
    --lr_warmup_steps=0 \
    --max_train_steps=1000 \
    --save_n_steps=20 \
    --validate_every_steps=50 \
    --vae_b16 \
    --gradient_checkpointing \
    --noise_offset=0.05 \
    --snr_gamma \
    --test_prompts="man sits at a table in a cafe, he greets another man with a smile and a handshakes"
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# usage: fine_tune.py [-h]
#                     [--pretrained_model_name_or_path PRETRAINED_MODEL_NAME_OR_PATH]
#                     [--unet_resume_path UNET_RESUME_PATH] --data_dir DATA_DIR
#                     [--report_to REPORT_TO] [--run_validation_at_start]
#                     [--max_vae_encode MAX_VAE_ENCODE] [--vae_b16]
#                     [--disable_optimizer_restore] [--latent_nan_checking]
#                     [--test_prompts TEST_PROMPTS]
#                     [--project_name PROJECT_NAME] [--run_name RUN_NAME]
# ...

# %%
# !accelerate launch Hotshot-XL/fine_tune.py \
    --output_dir="/home/vitap/Desktop/t2v dataset/Default Size" \
    --data_dir="/home/vitap/Desktop/t2v dataset/new" \
    --report_to="wandb" \
    --run_validation_at_start \
    --resolution=512 \
    --mixed_precision="fp16" \
    --train_batch_size=4 \
    --learning_rate=1.25e-05 \
    --lr_scheduler="constant" \
    --lr_warmup_steps=0 \
    --max_train_steps=1000 \
    --save_n_steps=20 \
    --validate_every_steps=50 \
    --vae_b16 \
    --gradient_checkpointing \
    --noise_offset=0.05 \
    --snr_gamma \
    --test_prompts="man sits at a table in a cafe, he greets another man with a smile and a handshakes"

# %%
# %cd   /home/vitap/Desktop/Hotshot-XL/Hotshot-XL
# !accelerate launch fine_tune.py \
    --output_dir="/home/vitap/Desktop/t2v dataset/Default Size" \
    --data_dir="/home/vitap/Desktop/t2v dataset/fine_tune_dataset" \
    --report_to="wandb" \
    --run_validation_at_start \
    --resolution=512 \
    --mixed_precision="fp16" \
    --train_batch_size=4 \
    --learning_rate=1.25e-05 \
    --lr_scheduler="constant" \
    --lr_warmup_steps=0 \
    --max_train_steps=1000 \
    --save_n_steps=20 \
    --validate_every_steps=50 \
    --vae_b16 \
    --gradient_checkpointing \
    --noise_offset=0.05 \
    --snr_gamma \
    --test_prompts="man sits at a table in a cafe, he greets another man with a smile and a handshakes" \
    --logging_dir="logs"
# Out:
# /home/vitap/Desktop/Hotshot-XL/Hotshot-XL
# wandb: Currently logged in as: sanjay7178 (mphoenix). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /home/vitap/Desktop/Hotshot-XL/Hotshot-XL/wandb/run-20231122_174758-avxbkeis
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run deft-cosmos-36
# wandb: ⭐️ View project at https://wandb.ai/mphoenix/fine-tune-hotshot-xl
# wandb: 🚀 View run at https://wandb.ai/mphoenix/fine-tune-hotshot-xl/runs/avxbkeis
# ...
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00, 68.17it/s]
# Warning - setting num_images_per_prompt = 1 because video_length = 8
#
# ...
# 100%|███████████████████████████████████████████| 30/30 [00:12<00:00,  2.37it/s]
#
# ...
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 25.19it/s]
# Progress:|█                        |:   5%| | 50/1000 [04:54<1:28:47,  5.61s/it,
# ...

# %%
# %cd ~/Desktop/Hotshot-XL/Hotshot-XL
# Out:
# /home/vitap/Desktop/Hotshot-XL/Hotshot-XL

# %% [markdown]
# #### Testing

# %%
# !python inference.py --prompt="a girl jumping up and down with his puppy in her hand , hd, high quality" --output="puppy.gif" --pretrained_path='Hotshot-XL'

# %%
# %cd ~/Desktop/Hotshot-XL 
# !python inference.py --prompt="ship moving around, biggest thunderstorm of the sea, lightening all over the sky, aggressive waves hitting the ship, ship trying to survive, cinematic, ultra realistic, burning ship" --negative_prompt="disfigured" \
    --output="Hotshot-XL/14output-1.gif" --pretrained_path='Hotshot-XL/Hotshot-XL'
# Out:
# /home/vitap/Desktop/Hotshot-XL
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.96it/s]
# Warning - setting num_images_per_prompt = 1 because video_length = 8
# ...
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 29.37it/s]
# Inference time taken:  11.07754898071289

# %%
# %cd ~/Desktop/Hotshot-XL 
# !python inference.py --prompt="ship moving around, biggest thunderstorm of the sea, lightening all over the sky, aggressive waves hitting the ship, ship trying to survive, cinematic, ultra realistic , burning ship"   --negative_prompt="disfigured" \
     --output="Hotshot-XL/14output-2.gif" --pretrained_path='Hotshot-XL/finetuned2'
# Out:
# /home/vitap/Desktop/Hotshot-XL
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.87it/s]
# Warning - setting num_images_per_prompt = 1 because video_length = 8
# ...
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 29.63it/s]
# Inference time taken:  10.948805809020996

# %%
# !python inference.py \
  --prompt="a bulldog in the captains chair of a spaceship, hd, high quality" \
  --output="output1.gif" \
  --video_length=16 \
  --video_duration=2000
#   --pretrained_path='Hotshot-XL' \
# Out:
# ...
# Fetching 18 files:  11%|██▊                      | 2/18 [00:00<00:07,  2.27it/s]
# ...
#
# ...
#
#
# ...
#
#
# ...
#
# ...
#
# ...
# Fetching 18 files:  17%|████▏                    | 3/18 [00:01<00:06,  2.34it/s]
# ...
#
# ...
#
#
# ...
#
#
# ...
#
#
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
# ...
#
# ...
#
#
#
# ...
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
#
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
# ...
#
# ...
#
# ...
#
#
# ...
#
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
#
# ...
#
# ...
#
# ...
#
#
# ...
#
#
#
#
# ...
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
# ...
#
# ...
#
# ...
#
# ...
#
#
#
#
# ...
#
#
# ...
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
# ...
#
# ...
#
# ...
#
#
# ...
#
#
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
# ...
#
#
#
# Fetching 18 files:  22%|█████▌                   | 4/18 [00:13<01:10,  5.00s/it]
#
#
# ...
#
#
# ...
#
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
#
# ...
#
#
# ...
#
# ...

# %%
# %cd '/home/vitap/Desktop/Hotshot-XL/Hotshot-XL/finetuned'
from huggingface_hub import notebook_login

notebook_login()
# Out:
# /home/vitap/Desktop/Hotshot-XL/Hotshot-XL/finetuned
# ...

# %%
# !ls
# Out:
# model_index.json  text_encoder	  tokenizer    unet
# scheduler	  text_encoder_2  tokenizer_2  vae

# %% [markdown]
# #### Model Push to HuggingFace

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token: Traceback (most recent call last):
#   File "/home/vitap/miniconda3/envs/hotshot/bin/huggingface-cli", line 8, in <module>
#     sys.exit(main())
#   File "/home/vitap/miniconda3/envs/hotshot/lib/python3.9/site-packages/huggingface_hub/commands/huggingface_cli.py", line 45, in main
# ...

# %%
# %cd ~/Desktop/Hotshot-XL/Hotshot-XL
# !python push_to_hub.py  --pretrained_path='finetuned'
# Out:
# /home/vitap/Desktop/Hotshot-XL/Hotshot-XL
# Loading pipeline components...: 100%|█████████████| 7/7 [00:06<00:00,  1.11it/s]
# model.safetensors:   0%|                             | 0.00/246M [00:00<?, ?B/s]
# model.safetensors:   0%|                            | 0.00/1.39G [00:00<?, ?B/s]
#
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/5.61G [00:00<?, ?B/s]
#
#
# Upload 4 LFS files:   0%|                                 | 0/4 [00:00<?, ?it/s]
#
#
#
# diffusion_pytorch_model.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
#
#
# model.safetensors:   0%|                    | 16.4k/246M [00:00<52:55, 77.5kB/s]
#
# diffusion_pytorch_model.safetensors:   0%| | 16.4k/5.61G [00:00<22:59:35, 67.8kB
# model.safetensors:   1%|                    | 1.34M/246M [00:00<00:48, 5.07MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   1%|   | 967k/167M [00:00<00:45, 3.69MB/s]
#
# diffusion_pytorch_model.safetensors:   0%| | 377k/5.61G [00:00<1:12:06, 1.30MB/s
# ...

# %% [markdown]
# ### Dec 10 finetuning

# %%
# %cd  /home/vitap/Desktop/Hotshot-XL/Hotshot-XL
# !accelerate launch fine_tune.py \
    --output_dir="/home/vitap/Desktop/Hotshot-XL/Hotshot-XL/finetuned2" \
    --data_dir="/home/vitap/Desktop/client/t2v_dataset_/fine_tune_dataset" \
    --report_to="wandb" \
    --run_validation_at_start \
    --resolution=512 \
    --mixed_precision="fp16" \
    --train_batch_size=4 \
    --learning_rate=1.25e-05 \
    --lr_scheduler="constant" \
    --lr_warmup_steps=0 \
    --max_train_steps=1000 \
    --save_n_steps=20 \
    --validate_every_steps=50 \
    --vae_b16 \
    --gradient_checkpointing \
    --noise_offset=0.05 \
    --snr_gamma \
    --test_prompts="man sits at a table in a cafe, he greets another man with a smile and a handshakes" \
    --logging_dir="logs"
# Out:
# /home/vitap/Desktop/Hotshot-XL/Hotshot-XL
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# wandb: Currently logged in as: sanjay7178 (mphoenix). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /home/vitap/Desktop/Hotshot-XL/Hotshot-XL/wandb/run-20231210_184534-q80wqjli
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run quiet-bee-37
# wandb: ⭐️ View project at https://wandb.ai/mphoenix/fine-tune-hotshot-xl
# ...
